# %% [markdown]
# <a href="https://colab.research.google.com/github/DiyaBansal0325/training-python/blob/main/Day%209.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas is an open source library that is used to handle data manipulation
#Data Structure of Pandas:
#1.) Series
#2.) Data Frame

# %%
#Series:
#It is one dimensional array and it shows only values not the column names

# %%
import pandas as pd
a = pd.Series([1,20,5,14,10])
a
# Out:
# 0     1
# 1    20
# 2     5
# 3    14
# 4    10
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
#DataFrame:
#It is multidimensional arry and it has values with column name

# %%
a = {
    "Name":['Sam','Raj','Rahul','Gaurav'],
    "Domain":['D.E.','D.S.','D.S.','Full Stack'],
    "Duration":[30,15,45,30]
}
df = pd.DataFrame(a)
df
# Out:
#      Name      Domain  Duration
# 0     Sam        D.E.        30
# 1     Raj        D.S.        15
# 2   Rahul        D.S.        45
# 3  Gaurav  Full Stack        30

# %%
df.to_csv("intern_stu.csv")

# %%
df = pd.read_csv("/content/Best_hotel.csv")
df
# Out:
#                                                  Name  \
# 0                                        The Magnolia
# 1                 J Brew & Kitchen Rooftop Restaurant
# 2                                       Suvarna Mahal
# 3                                                 NaN
# 4                                    Govindam Retreat
# 5                                  Skyfall Restaurant
# 6                                  Peacock Restaurant
# 7   Annpoornam - Best South Indian Restaurant In J...
# 8                                  Monarch Restaurant
# 9        Brewlicious Rooftop Bar Restaurant in Jaipur
# 10                                          Zolocrust
# 11                                       Thali & more
# 12                            Handi restaurant jaipur
# 13                    Jaipur Modern - Store & Kitchen
# 14  Bada Saab - The heritage kitchen | Restaurant ...
# 15                                          SambharSa
# ...

# %%
df = pd.read_csv("/content/Best_Buses.csv")

# %%
df
# Out:
#     Ratings                                       Travels Name  \
# 0       4.0                                  Ram Dalal Travels
# 1       3.1  Shri Krishna Travels(Jai Shree Ganesh Yatra Co...
# 2       4.0                    Mahalaxmi Travels ISO 9001:2015
# 3       3.6  Shri Krishna Travels(Jai Shree Ganesh Yatra Co...
# 4       3.1                    Mahalaxmi Travels ISO 9001:2015
# 5       4.4                            Rinku And Yuvraj Travel
# 6       4.6                                      Vikas Travels
# 7       3.9                                            FlixBus
# 8       3.4                    Mahalaxmi Travels ISO 9001:2015
# 9       3.7                         Shree Raj Ankanshi Travels
# 10      3.5                                    Samreen Travels
# 11      3.1  Shri Krishna Travels(Jai Shree Ganesh Yatra Co...
# 12      2.6                              Ravina Travels (Regd)
# 13      4.2                             Laxmi Holidays Pvt Ltd
# ...
